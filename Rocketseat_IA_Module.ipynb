# %% [markdown]
# <a href="https://colab.research.google.com/github/jairosl/artificial_intelligence_python/blob/main/Rocketseat_IA_Module.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Modulo de Estatística

# %% [markdown]
# ## Sub Áreas
# 1.   Probanilidade - Eventos Aléatorio
# 2.   Estatística - Coleta, Organização, Resumo de dados, Padrão, Tendência e Caracteristicas
# 3.   Inferência - Previsões

# %% [markdown]
# ## Conceitos
#
#
#
# 1.   População - Se refere a todo o conjunto de elementos que compartilham uma característica
# 2.   Amostra - Subconjunto selecionado da população

# %% [markdown]
# ## Variáveis
#
# 1.   Quantitativas - Números, Continua, Discretas
#
# 2.   Qualitativas - Categoria, Nominais, Ordinais

# %% [markdown]
# ## Teorema do Limite Central
#
#
#
# > Quando você extrai várias amostras aleatórias de uma população e calcula e medida de cada um, independente da forma de distribuição geral, essas medidas se aproximam de uma distribuição normal (Formato de sino) à medida que o tamanho aumenta. nos permitindo fazer inferência de uma população com base em uma amostra

# %% [markdown]
# ## Colocando em Prática - Introdução a python e estatística

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 1.5.3

# %%
dict_medidas = {'idade': [15,18, 25, 25, 40, 55, 58, 60, 80], 'altura': [160, 162, 165, 168, 172, 174, 174, 174, 176]}

# %%
dict_medidas
# Out:
# {'idade': [15, 18, 25, 25, 40, 55, 58, 60, 80],
#  'altura': [160, 162, 165, 168, 172, 174, 174, 174, 176]}

# %%
df_medidas = pd.DataFrame.from_dict(dict_medidas)

# %%
df_medidas
# Out:
#    idade  altura
# 0     15     160
# 1     18     162
# 2     25     165
# 3     25     168
# 4     40     172
# 5     55     174
# 6     58     174
# 7     60     174
# 8     80     176

# %% [markdown]
# ## Medidas Resumo

# %% [markdown]
# ### Medidas Posição

# %%
df_medidas.mean()
# Out:
# idade      41.777778
# altura    169.444444
# dtype: float64

# %%
df_medidas.median()
# Out:
# idade      40.0
# altura    172.0
# dtype: float64

# %%
df_medidas.mode()
# Out:
#    idade  altura
# 0     25     174

# %% [markdown]
# ### Medidas de Disperção

# %%
# Variancia

df_medidas.var()
# Out:
# idade     509.944444
# altura     34.777778
# dtype: float64

# %%
# Desvio Padrão

df_medidas.std()
# Out:
# idade     22.581950
# altura     5.897269
# dtype: float64

# %%
# Coeficiente de variação

df_medidas.std() / df_medidas.mean() * 100
# Out:
# idade     54.052539
# altura     3.480355
# dtype: float64

# %% [markdown]
# ### Medida de Forma

# %%
# Assimetria

df_medidas.skew()
# Out:
# idade     0.368109
# altura   -0.598487
# dtype: float64

# %%
# Curtose

df_medidas.kurtosis()
# Out:
# idade    -1.134446
# altura   -1.337264
# dtype: float64

# %%
# Obter medidas estátistica

df_medidas.describe()
# Out:
#            idade      altura
# count   9.000000    9.000000
# mean   41.777778  169.444444
# std    22.581950    5.897269
# min    15.000000  160.000000
# 25%    25.000000  165.000000
# 50%    40.000000  172.000000
# 75%    58.000000  174.000000
# max    80.000000  176.000000

# %% [markdown]
# ## Correlações

# %%
df_medidas.corr(method="pearson")
# Out:
#            idade    altura
# idade   1.000000  0.931024
# altura  0.931024  1.000000

# %%
df_medidas.corr(method="spearman")
# Out:
#            idade    altura
# idade   1.000000  0.978803
# altura  0.978803  1.000000

# %%
df_medidas.corr(method="kendall")
# Out:
#            idade    altura
# idade   1.000000  0.941584
# altura  0.941584  1.000000

# %%
df_medidas.altura.corr(df_medidas.idade, method="pearson")
# Out:
# 0.931023604505434

# %% [markdown]
# ## Representação Gráfica

# %%
# !pip install matplotlib

# %%
# Data Frame Vendas

dict_vendas = {"categoria": ['masculino', "feminino", "infantil", "casa"], "valor":[400000, 600000, 250000, 580000], "quantidade": [3000, 5000, 1500, 2500]}

df_vendas = pd.DataFrame.from_dict(dict_vendas)

df_vendas
# Out:
#    categoria   valor  quantidade
# 0  masculino  400000        3000
# 1   feminino  600000        5000
# 2   infantil  250000        1500
# 3       casa  580000        2500

# %% [markdown]
# ### Plot Histograma

# %%
df_medidas.hist()
# Out:
# array([[<Axes: title={'center': 'idade'}>,
#         <Axes: title={'center': 'altura'}>]], dtype=object)

# %% [markdown]
# ### Grafico de Barras

# %%
# Vertical

df_vendas.plot.bar(x="categoria", y="valor")
# Out:
# <Axes: xlabel='categoria'>

# %%
# Ordenado

df_vendas.sort_values("valor").plot.bar(x="categoria", y="valor")
# Out:
# <Axes: xlabel='categoria'>

# %%
# Horizontal

df_vendas.sort_values("quantidade").plot.barh(x="categoria", y="quantidade")
# Out:
# <Axes: ylabel='categoria'>

# %% [markdown]
# ### Grafico de Dispersão

# %%
df_medidas.plot.scatter(x="idade", y="altura" )
# Out:
# <Axes: xlabel='idade', ylabel='altura'>

# %% [markdown]
# ### Gráfico Boxplot

# %%
df_medidas.idade.plot.box()
# Out:
# <Axes: >

# %%
df_medidas.altura.plot.box()
# Out:
# <Axes: >

# %% [markdown]
# ### Gráfico de Linhas

# %%
dict_faturamento = {"data_ref": ["2019-01-01","2020-01-01", "2021-01-01", "2022-01-01", "2023-01-01"], "valor": [400000, 800000, 500000, 800000, 900000]}
df_faturamento = pd.DataFrame.from_dict(dict_faturamento)
df_faturamento
# Out:
#      data_ref   valor
# 0  2019-01-01  400000
# 1  2020-01-01  800000
# 2  2021-01-01  500000
# 3  2022-01-01  800000
# 4  2023-01-01  900000

# %%
df_faturamento.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   data_ref  5 non-null      object
#  1   valor     5 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 208.0+ bytes

# %%
df_faturamento['data_ref'] = pd.to_datetime(df_faturamento["data_ref"])
df_faturamento.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   data_ref  5 non-null      datetime64[ns]
#  1   valor     5 non-null      int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 208.0 bytes

# %%
graph = df_faturamento.plot.line(x="data_ref", y="valor")
graph.set_xlabel("Ano")
graph.set_ylabel("Valor")
graph
# Out:
# <Axes: xlabel='Ano', ylabel='Valor'>

# %% [markdown]
# # Analise Exploratória

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pathDatasets = "/content/drive/MyDrive/Colab/datasets_eda"

# %% [markdown]
# ## Criar DataFrames com base nos Datasets

# %%
# Load dataframe customers, services and contracts

df_customers = pd.read_csv(f'{pathDatasets}/churn_customers.csv')
df_contracts = pd.read_csv(f'{pathDatasets}/churn_contracts.csv')
df_services = pd.read_csv(f'{pathDatasets}/churn_services.csv')

# %%
# Show frist five lines
df_customers.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents
# 0  7590-VHVEG  Female              0     Yes         No
# 1  5575-GNVDE    Male              0      No         No
# 2  3668-QPYBK    Male              0      No         No
# 3  7795-CFOCW    Male              0      No         No
# 4  9237-HQITU  Female              0      No         No

# %%
# Show last five lines
df_customers.tail()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents
# 7038  6840-RESVB    Male              0     Yes        Yes
# 7039  2234-XADUH  Female              0     Yes        Yes
# 7040  4801-JZAZL  Female              0     Yes        Yes
# 7041  8361-LTMKD    Male              1     Yes         No
# 7042  3186-AJIEK    Male              0      No         No

# %%
# Endender a estrutura/schema do dataframe
df_customers.info()
df_contracts.info()
df_services.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     7043 non-null   object
#  1   gender         7043 non-null   object
#  2   SeniorCitizen  7043 non-null   int64
#  3   Partner        7043 non-null   object
#  4   Dependents     7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   tenure            7043 non-null   int64
#  2   Contract          7043 non-null   object
#  3   PaperlessBilling  7043 non-null   object
#  4   PaymentMethod     7043 non-null   object
#  5   MonthlyCharges    7043 non-null   float64
# ...

# %% [markdown]
# ## Transformação dos Dados

# %%
# Transforma coluna TotalCharges de string para float

# df_contracts["TotalCharges"] = df_contracts["TotalCharges"].astype(float)
# vai dar error pois tem string nessa coluna


# df_contracts["TotalCharges"] = pd.to_numeric(df_contracts["TotalCharges"])
# vai dar error pois tem string nessa coluna


df_contracts["TotalCharges"] = pd.to_numeric(df_contracts["TotalCharges"], errors='coerce')

# %%
df_contracts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   tenure            7043 non-null   int64
#  2   Contract          7043 non-null   object
#  3   PaperlessBilling  7043 non-null   object
#  4   PaymentMethod     7043 non-null   object
#  5   MonthlyCharges    7043 non-null   float64
#  6   TotalCharges      7032 non-null   float64
#  7   Churn             7043 non-null   object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 440.3+ KB

# %% [markdown]
# > 11 valores ausentes (missing values) após a transformação

# %% [markdown]
# ## Remonemar Colunas

# %%
# Renomear coluna no DataFrame
df_customers.rename(columns={"SeniorCitizen": "Above65yo"}, inplace=True)

# %%
df_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7043 non-null   object
#  1   gender      7043 non-null   object
#  2   Above65yo   7043 non-null   int64
#  3   Partner     7043 non-null   object
#  4   Dependents  7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB

# %%
df_customers.columns = ["IDCliente", "Genero", "Mais65anos", "TemParceiro", "TemDependentes"]

# %%
df_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   IDCliente       7043 non-null   object
#  1   Genero          7043 non-null   object
#  2   Mais65anos      7043 non-null   int64
#  3   TemParceiro     7043 non-null   object
#  4   TemDependentes  7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB

# %% [markdown]
# ## Unificando DataFrames

# %%
# Quantidade de registro por DataFrame
len(df_customers)
len(df_contracts)
len(df_services)
# Out:
# 7043

# %%
df_services.rename(columns={"customerID": "IDCliente"}, inplace=True)

# %%
df_services.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   IDCliente         7043 non-null   object
#  1   PhoneService      7043 non-null   object
#  2   MultipleLines     7043 non-null   object
#  3   InternetService   7043 non-null   object
#  4   OnlineSecurity    7043 non-null   object
#  5   OnlineBackup      7043 non-null   object
#  6   DeviceProtection  7043 non-null   object
#  7   TechSupport       7043 non-null   object
#  8   StreamingTV       7043 non-null   object
#  9   StreamingMovies   7043 non-null   object
# dtypes: object(10)
# memory usage: 550.4+ KB

# %%
# Unificando DataFrames de Customer e Services

df_temp = df_customers.merge(df_services, on=["IDCliente"])

# %%
df_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   IDCliente         7043 non-null   object
#  1   Genero            7043 non-null   object
#  2   Mais65anos        7043 non-null   int64
#  3   TemParceiro       7043 non-null   object
#  4   TemDependentes    7043 non-null   object
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
# dtypes: int64(1), object(13)
# memory usage: 825.4+ KB

# %%
# Unificar DataFrame Temp com Contract

df_churn_temp = df_temp.merge(df_contracts, left_on=["IDCliente"], right_on=["customerID"])

# %%
df_churn_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   IDCliente         7043 non-null   object
#  1   Genero            7043 non-null   object
#  2   Mais65anos        7043 non-null   int64
#  3   TemParceiro       7043 non-null   object
#  4   TemDependentes    7043 non-null   object
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  customerID        7043 non-null   object
#  15  tenure            7043 non-null   int64
# ...

# %%
df_churn = df_customers.merge(df_services, on=["IDCliente"]).merge(df_contracts, left_on=["IDCliente"], right_on=["customerID"])

# %%
df_churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   IDCliente         7043 non-null   object
#  1   Genero            7043 non-null   object
#  2   Mais65anos        7043 non-null   int64
#  3   TemParceiro       7043 non-null   object
#  4   TemDependentes    7043 non-null   object
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  customerID        7043 non-null   object
#  15  tenure            7043 non-null   int64
# ...

# %%
# Remover Col customerID

df_churn.drop(["customerID"], axis=1, inplace=True)
#  axis=1 determinar que vamos usar coluna

# %%
df_churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   IDCliente         7043 non-null   object
#  1   Genero            7043 non-null   object
#  2   Mais65anos        7043 non-null   int64
#  3   TemParceiro       7043 non-null   object
#  4   TemDependentes    7043 non-null   object
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  tenure            7043 non-null   int64
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# ## Detecção de Valores Ausentes

# %%
# detectar valores ausentes em todas a colunas do DataFrame

df_churn.isna().sum()
# Out:
# IDCliente            0
# Genero               0
# Mais65anos           0
# TemParceiro          0
# TemDependentes       0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# tenure               0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
# Detectar por coluna específica
df_churn.TotalCharges.isna().sum()
# Out:
# 11

# %%
# Quantas linhas tem pelo menos 1 coluna com valor ausente

df_churn[df_churn.isna().any(axis=1)]
# Out:
#        IDCliente  Genero  Mais65anos TemParceiro TemDependentes PhoneService  \
# 488   4472-LVYGI  Female           0         Yes            Yes           No
# 753   3115-CZMZD    Male           0          No            Yes          Yes
# 936   5709-LVOEQ  Female           0         Yes            Yes          Yes
# 1082  4367-NUYAO    Male           0         Yes            Yes          Yes
# 1340  1371-DWPAZ  Female           0         Yes            Yes           No
# 3331  7644-OMVMY    Male           0         Yes            Yes          Yes
# 3826  3213-VVOLG    Male           0         Yes            Yes          Yes
# 4380  2520-SGTTA  Female           0         Yes            Yes          Yes
# 5218  2923-ARZLG    Male           0         Yes            Yes          Yes
# 6670  4075-WKNIU  Female           0         Yes            Yes          Yes
# 6754  2775-SEFEE    Male           0          No            Yes          Yes
#
# ...

# %%
# Quantas colunas tem pelo menos 1 valor ausente

df_churn.isna().any(axis=0).sum()
# Out:
# 1

# %% [markdown]
# ## Remover valores ausentes

# %%
# Remover de forma direta e especifica a coluna que possui valores ausentes

df_churn.drop(columns=["TotalCharges"], axis=1).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   IDCliente         7043 non-null   object
#  1   Genero            7043 non-null   object
#  2   Mais65anos        7043 non-null   int64
#  3   TemParceiro       7043 non-null   object
#  4   TemDependentes    7043 non-null   object
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  tenure            7043 non-null   int64
#  15  Contract          7043 non-null   object
# ...

# %%
# Remover colunas com valores ausentes

df_churn.dropna(axis=1)
# Out:
#        IDCliente  Genero  Mais65anos TemParceiro TemDependentes PhoneService  \
# 0     7590-VHVEG  Female           0         Yes             No           No
# 1     5575-GNVDE    Male           0          No             No          Yes
# 2     3668-QPYBK    Male           0          No             No          Yes
# 3     7795-CFOCW    Male           0          No             No           No
# 4     9237-HQITU  Female           0          No             No          Yes
# ...          ...     ...         ...         ...            ...          ...
# 7038  6840-RESVB    Male           0         Yes            Yes          Yes
# 7039  2234-XADUH  Female           0         Yes            Yes          Yes
# 7040  4801-JZAZL  Female           0         Yes            Yes           No
# 7041  8361-LTMKD    Male           1         Yes             No          Yes
# 7042  3186-AJIEK    Male           0          No             No          Yes
#
# ...

# %%
# Remover colunas onde todos os valores são ausentes

df_churn.dropna(axis=1, how="all").info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   IDCliente         7043 non-null   object
#  1   Genero            7043 non-null   object
#  2   Mais65anos        7043 non-null   int64
#  3   TemParceiro       7043 non-null   object
#  4   TemDependentes    7043 non-null   object
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  tenure            7043 non-null   int64
#  15  Contract          7043 non-null   object
# ...

# %%
# Remover as linhas com valores ausentes

df_churn.dropna(axis=0).count()
# Out:
# IDCliente           7032
# Genero              7032
# Mais65anos          7032
# TemParceiro         7032
# TemDependentes      7032
# PhoneService        7032
# MultipleLines       7032
# InternetService     7032
# OnlineSecurity      7032
# OnlineBackup        7032
# DeviceProtection    7032
# TechSupport         7032
# StreamingTV         7032
# StreamingMovies     7032
# tenure              7032
# Contract            7032
# PaperlessBilling    7032
# PaymentMethod       7032
# MonthlyCharges      7032
# TotalCharges        7032
# Churn               7032
# dtype: int64

# %%
# Remover linhas com todos os valores ausentes

df_churn.dropna(axis=0, how="all").count()
# Out:
# IDCliente           7043
# Genero              7043
# Mais65anos          7043
# TemParceiro         7043
# TemDependentes      7043
# PhoneService        7043
# MultipleLines       7043
# InternetService     7043
# OnlineSecurity      7043
# OnlineBackup        7043
# DeviceProtection    7043
# TechSupport         7043
# StreamingTV         7043
# StreamingMovies     7043
# tenure              7043
# Contract            7043
# PaperlessBilling    7043
# PaymentMethod       7043
# MonthlyCharges      7043
# TotalCharges        7032
# Churn               7043
# dtype: int64

# %% [markdown]
# ## Imputar Dados nos Valores Ausentes

# %%
# Preencher todos os valores ausentes com 0

df_churn.fillna(0)
# Out:
#        IDCliente  Genero  Mais65anos TemParceiro TemDependentes PhoneService  \
# 0     7590-VHVEG  Female           0         Yes             No           No
# 1     5575-GNVDE    Male           0          No             No          Yes
# 2     3668-QPYBK    Male           0          No             No          Yes
# 3     7795-CFOCW    Male           0          No             No           No
# 4     9237-HQITU  Female           0          No             No          Yes
# ...          ...     ...         ...         ...            ...          ...
# 7038  6840-RESVB    Male           0         Yes            Yes          Yes
# 7039  2234-XADUH  Female           0         Yes            Yes          Yes
# 7040  4801-JZAZL  Female           0         Yes            Yes           No
# 7041  8361-LTMKD    Male           1         Yes             No          Yes
# 7042  3186-AJIEK    Male           0          No             No          Yes
#
# ...

# %%
# Preencher valores padrão conforme a coluna

df_churn.fillna(value={"TotalCharges": 0})
# Out:
#        IDCliente  Genero  Mais65anos TemParceiro TemDependentes PhoneService  \
# 0     7590-VHVEG  Female           0         Yes             No           No
# 1     5575-GNVDE    Male           0          No             No          Yes
# 2     3668-QPYBK    Male           0          No             No          Yes
# 3     7795-CFOCW    Male           0          No             No           No
# 4     9237-HQITU  Female           0          No             No          Yes
# ...          ...     ...         ...         ...            ...          ...
# 7038  6840-RESVB    Male           0         Yes            Yes          Yes
# 7039  2234-XADUH  Female           0         Yes            Yes          Yes
# 7040  4801-JZAZL  Female           0         Yes            Yes           No
# 7041  8361-LTMKD    Male           1         Yes             No          Yes
# 7042  3186-AJIEK    Male           0          No             No          Yes
#
# ...

# %%
# Preencher todos os valores ausentes de uma coluna com a media

media_TotalCharges = df_churn.TotalCharges.mean()
media_TotalCharges
# Out:
# 2283.3004408418656

# %%
df_churn.fillna(value={"TotalCharges": media_TotalCharges})
# Out:
#        IDCliente  Genero  Mais65anos TemParceiro TemDependentes PhoneService  \
# 0     7590-VHVEG  Female           0         Yes             No           No
# 1     5575-GNVDE    Male           0          No             No          Yes
# 2     3668-QPYBK    Male           0          No             No          Yes
# 3     7795-CFOCW    Male           0          No             No           No
# 4     9237-HQITU  Female           0          No             No          Yes
# ...          ...     ...         ...         ...            ...          ...
# 7038  6840-RESVB    Male           0         Yes            Yes          Yes
# 7039  2234-XADUH  Female           0         Yes            Yes          Yes
# 7040  4801-JZAZL  Female           0         Yes            Yes           No
# 7041  8361-LTMKD    Male           1         Yes             No          Yes
# 7042  3186-AJIEK    Male           0          No             No          Yes
#
# ...

# %% [markdown]
# ## Analise Univariada

# %% [markdown]
# > Faixa etária do cliente tem uma forte associação com o Churn
#
#
# > Um Cliente com menos de 6 meses de contrato é mais propenso ao Churn
#
#
# > Cliente mensal é mais propenso ao Churn

# %%
# Como identificar valores possiveis em uma variavel do DataFrame
df_churn.Churn.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
# Contar clientes usando a variavel churn como referencia
df_churn.Churn.value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
# Obter os numero em percentual (Distribuição)
df_churn.Churn.value_counts(normalize=True) * 100
# Out:
# No     73.463013
# Yes    26.536987
# Name: Churn, dtype: float64

# %%
# Plot distribuição Churn (quantidade)

ax = df_churn.Churn.value_counts().plot.bar()

ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '5174'), Text(0, 0, '1869')]

# %%
# Plot distribuição Churn (Percentual)

ax = df_churn.Churn.value_counts(normalize=True).plot.bar()

ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '0.73463'), Text(0, 0, '0.26537')]

# %%
# Quais são os tipos de contratos
df_churn.Contract.unique()
# Out:
# array(['Month-to-month', 'One year', 'Two year'], dtype=object)

# %%
# Plot distribuição Contract (Percentual)

percentage = df_churn.Contract.value_counts(normalize=True) * 100
ax = percentage.plot.bar()

ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '55.0192'), Text(0, 0, '24.0664'), Text(0, 0, '20.9144')]

# %%
# Histograma do tempo de contrato

df_churn.tenure.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# *   A Variavel tempo contrato (tenure) não apresenta visual uma distribuição normal
#
#
# *   A grande parte dos valores se concentram nos extremo, ou seja, contratos com poucos meses de ativação e contratos com longos, acima aproximadamente dos 65 meses

# %%
# Histograma do Monthly Charges

df_churn.MonthlyCharges.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Medidas de Posição - Media Tempo de Contrato

df_churn.tenure.mean()
# Out:
# 32.37114865824223

# %%
# Medidas de Posição - Mediana Tempo de Contrato

df_churn.tenure.median()
# Out:
# 29.0

# %%
# Medidas de Posição - Tempo de contrato mais popular

df_churn.tenure.mode()
# Out:
# 0    1
# Name: tenure, dtype: int64

# %%
# Medidas de Disperção - Desvio Padrão

df_churn.tenure.std()
# Out:
# 24.55948102309446

# %%
# Medidas de Disperção - Coeficiente de variação

df_churn.tenure.std() / df_churn.tenure.mean() * 100
# Out:
# 75.86842617906674

# %%
# Quantos Clientes possuem um mes de contrato - Filtro
len(df_churn[(df_churn.tenure==1)])
# Out:
# 613

# %%
# Quantos Clientes com 1 mes de assinatura tem em porcentagem
len(df_churn[(df_churn.tenure==1)]) / len(df_churn) * 100
# Out:
# 8.70367741019452

# %%
# Quantos clientes tem entre 1 e 6 meses de contrato
len(df_churn[(df_churn.Genero=="Male") & (df_churn.tenure <=6)])
# Out:
# 746

# %%
# apresentar a quantidade de clientes por tempo de contrato - agrupamento de dados sumarizados

df_churn.groupby(["tenure"])["tenure"].count().sort_values(ascending=False)
# Out:
# tenure
# 1     613
# 72    362
# 2     238
# 3     200
# 4     176
#      ...
# 28     57
# 39     56
# 44     51
# 36     50
# 0      11
# Name: tenure, Length: 73, dtype: int64

# %%
df_churn.groupby(["tenure"])["tenure"].count().sort_values().plot.barh(figsize=(20, 20))
# Out:
# <Axes: ylabel='tenure'>
